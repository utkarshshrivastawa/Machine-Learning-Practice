# %% [markdown]
# # Machine Learning Model
# ## A ML model is a function that tries to find the relationship between the features and the target variable

# %% [markdown]
# ### Model Selection
# In Machine Learning is the process of choosing the best suited model for a particular problem. Selecting a model depends on various factors such as the dataset, task, nature of the model, etc.

# %% [markdown]
# ### Models can be selected based on:
# 1. Type of Data available:
#     1. Images & Videos - CNN
#     2. Text data or Speech data - RNN
#     3. Numerical data - SVM, Logistic Regression, Decision trees, etc.
# 2. Based on the task we need to carry out:
#     1. Classification tasks - SVM, Logistic Regression, Decision trees, etc.
#     2. Regression tasks - Linear regression, Random Forest, Polynomial regression, etc.
#     3. Clustering tasks - K-Means Clustering, Hierarchical Clustering

# %% [markdown]
# #### Overfitting in ml issues
# Overfitting refers to a model that models the training data too well. Overfitting happens when a model learns the detail and noise in the training dataset to the extent that it negatively impacts the performance of the model.
# ![image.png](attachment:947ca431-7949-4043-903f-868ef04f7407.png)
# ______________________________________________________________________________________________________
# sign for the model has overfitted : high training data Accuracy and ver low test data Accuracy
# ##### Cause for overfitting
# 1. Less data
# 2. Increased complexity of the model
# 3. more no. of layers in neural networks
#
# ##### Preventing Overfitting by
# 1. Using more data
# 2. Reduce the no. of layers in the neural networks
# 3. Early Stopping
# 4. Bias - Variance Tradeoff
# 5. Use Dropouts

# %% [markdown]
# #### Underfitting in ml issue
# Underfitting happens when the moglel does not learn enough from the data. Underfitting occurs when a machine learning model cannot capture the underlying trend of the data
# ![image.png](attachment:cd008f3b-c448-465f-87ce-d9d22f998c14.png)
# ______________________________________________________________________________________________________
# sign for the model has Underfitting : VERy low training data Accuracy
# ##### Cause for underfitting
# 1. Choosing ta wrong model
# 2. Less complexity of the model
# 3. Less Variance but  high bias
#
# ##### Preventing underfitting by
# 1. Choosing the correct model appropriate for the problem
# 2. Increasing the complexity of the model
# 3. More number of parameters to the model
# 4. Bias - Variance Tradeoff

# %% [markdown]
# #### Bias
# Bias is the difference between the average prediction of our model and the correct value which we are trying to predict.
# #### Variance :
# It is the amount that the estimate of the target funvtion will change if different data was used.
#
# ![image.png](attachment:683c93d8-c133-4d68-8b40-559dc4092a85.png)
# ______________________________________________________________________________________________________
# ##### Techniques to have better Bias-Variance Tradeoff:
# 1. Good Model Selection
# 2. Regularization
# 3. Dimensionality Reduction
# 4. Ensemble methods

# %% [markdown]
# ### Loss Function
# The Loss function is a method of evaluating how well your algorithm is modeling your dataset.It is a mathematical function of the parameters of the machine learning algorithm.Tells the distance between value predicited by model and the true values & it dependence on the probability.It is the error made by the model. Low loss values --> High Accuracy.
#
# ![image.png](attachment:193fe6fb-0f84-49a4-88ed-439dcf1861b5.png)
# ______________________________________________________________________________________________________
# Type of Loss function:
# 1. Cross Entropy loss
# 2. Squared Error Loss
# 3. KL Divergence

# %% [markdown]
# ### Model Evaluation:
# Works flow of the ml project :
# 1. Data Collection
# 2. Data Pre- processing
# 3. Data Analysis
# 4. Train Test Split
# 5. Feed training data in machine learning model
# 6. Model Evaluation(metric)
#
# Evaluation metric for
# 1. Classsification : Accuracy score(It is the reation of no. of correct predictions to the total no. of input data points.)
# 2. Regression : Mean Absolute Error(Mean Squared Error measures the average of the squares of the errors, that is, the average squared difference between the estimated values and the actual value).Formula : ![image.png](attachment:8e94e9e8-6a32-4f34-945c-02552a55dd43.png)

# %% [markdown]
# ###  Parameters
# Slpoe and intercept are parameters.
# #### Model Parameters
# These are the parameters of the model that can be determined by training with training data. These can be considered as internal Parameters.
# 1. Weights : It decides how much influence the input will have on the output.
# 2. Bias  : It is the offset values given to the model . Bias is used to shift the model in a particular direction. It is similar to a Y-intercept.'b' is equal to 'y' when all the features values are zero
# ![image.png](attachment:59fb62de-c189-4578-bee8-e02da24f91aa.png)
#
# ### Hyperparameters
# Hyperparameters are parameters whose values control the learning process. These are adjustable parameters used to obtain an optimal model. External Parameters.
# 1. Learning rate:It is a tuning parameter in an optimization algorithm that determines the stp size at each iteration while moving forward a minimum of a loss function
# 2. No. Of Epochs : It represent thenumber of lines of times the model iterates over the entire dataset.

# %% [markdown]
# ### Gradient Descent :
# It is a model optimization model . So , best parameters (Gradient Descent is used) , Global mimimum is a point where model predict best output . we can gradualy change the value for best output . and formal is
#
# ![image.png](attachment:75cdf276-b120-4638-8b32-1ead5300dec6.png)
# ![image.png](attachment:2ca99676-d4a2-4bc9-969d-e9133113a55f.png)
#
# ### Model Optimizatiom model :
# It refers to determining best parameters for a model , such that the loss function of the model decreases , as a result of which the model can predict more accurately
