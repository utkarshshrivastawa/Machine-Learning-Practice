# %% [markdown]
# Artificial Intelligence
#
# AI is a branch of Computer Science that is concerned with building smart & intelligent Machine

# %% [markdown]
# Deep Learning
#
# Deep learning is the subfield of Machine learning that uses Artificial Neural Networks to learn from the data
#
# Diagram of Deep Learning :
# ![image-2.png](attachment:image-2.png)
#
# Layers are :
# 1. Input Layer
# 2. Hidden Layer
# 3. Output Layer
#
# Application
#
# 1. Healthcare
# 2. Autonomous cars
# 3. Computer Vision
# 4. Natral Language Processing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Machine learning
#
# Machine Learning is a technique to implement AI that can learn from the data by themseleves without being explicitly programmed

# %% [markdown]
# Types of Machine Learning
#
# 1. Supervised Learning
# 2. Unsupervised Learning
# 3. Reinforcement Learning

# %% [markdown]
# Supervised Learning
#
# In Supervised Learning the Machine Learning algorithm learn from Labelled Data
#
# Types of Supervised Learning
# 1. Classification :
# It is about predictiong a class or discrete values . Examples : True or False
#
# Algorithms
# 1. Decision Tree Classification
# 2. Random Forest Classification
# 3. K-Nearest Neighbor
# ____________________________________________________________________
#
# 2. Regression :
# It is about pedicting a quantity or continous values.Examples :Salary,age.
#
# Algorithms
# 1. Logistic Regression
# 2. Polynomial Regression
# 3. Support Vector Machines

# %% [markdown]
# Unsupervised Learning
#
# In Unsupervised Learning the Machine Learning algorithm learn from unlabelled Data
#
# Types of unsupervised Learning
#
# 1. Clustering
# It is an unsupervised task which involves grouping the similar data points.
#
# Algorithms
# 1. K-Means Clustering
# 2. Hierarchical Clustering
# 3. Principal Component Analysis(PCA)
# ____________________________________________________________________________
# 2. Association
# It is an unsupervised task that is used to find important relationship between data points.
#
# Algorithms
# 1. Apriori
# 2. Eclat

# %% [markdown]
# Reinforcement Learning
#
# Reinforcement Learning is an area of machine learning concerned with how intelligent agents takes in an environment to maximize its rewards.
#
# 1. Environment
# 2. Agent
# 3. Action
# 4. Reward
